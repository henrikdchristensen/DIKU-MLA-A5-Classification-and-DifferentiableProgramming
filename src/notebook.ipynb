# %% [markdown]
# # 1. Sleep well (35 points)

# %%
n_jobs = 2
cv = 3
scoring = 'accuracy'
digits = 4

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Load the data
X_train = pd.read_csv('data\Sleep-EDF-15_U-Time/X_train.csv', header=None)
y_train = pd.read_csv('data\Sleep-EDF-15_U-Time/y_train.csv', header=None)
X_test = pd.read_csv('data\Sleep-EDF-15_U-Time/X_test.csv', header=None)
y_test = pd.read_csv('data\Sleep-EDF-15_U-Time/y_test.csv', header=None)

# Normalize the data according to the training set
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## 1.1 Data understanding and preprocessing

# %%
import matplotlib.pyplot as plt

# Calculate class frequencies for training data, normalized to [0,1]
class_frequencies = y_train.value_counts(normalize=True).sort_index()

# Print each class frequency for training data
print('Class frequencies for training data:')
for label, freq in class_frequencies.items():
    print(f'Class {label}: {freq*100:.2f}%')

# Plotting
labels = [f'Class {i}' for i in range(0, 5)]
freqs = class_frequencies.values * 100

plt.figure(figsize=(4, 3))
bars = plt.bar(labels, freqs, color=plt.cm.tab10.colors, alpha=0.5)

# Add annotations to bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 1, f'{yval:.2f}%', ha='center', va='bottom')

plt.ylabel('Frequency (%)')
plt.title('Class Frequencies for Training set', fontsize=14, y=1.04)
plt.ylim(0, 105)  # Adjusted to make space for annotations
plt.grid(axis='y')
plt.tight_layout()
plt.show()
# Out:
# Class frequencies for training data:
# Class (0.0,): 52.09%
# Class (1.0,): 9.55%
# Class (2.0,): 25.27%
# Class (3.0,): 4.69%
# Class (4.0,): 8.39%

# %% [markdown]
# ## 1.2 Classification

# %% [markdown]
# ### Helper methods to hyperparameter tuning, evaluation and plotting

# %%
from sklearn.metrics import classification_report, zero_one_loss
from sklearn.model_selection import GridSearchCV
import matplotlib.pyplot as plt
import numpy as np

def hyperparameter_tuning(estimator, param_grid, X_train, y_train, cv, n_jobs, scoring):
    grid_search = GridSearchCV(estimator=estimator,
                               param_grid=param_grid,
                               return_train_score=True,
                               cv=cv,
                               n_jobs=n_jobs,
                               scoring=scoring)
    grid_search.fit(X_train, y_train.values.ravel())
    best_model = grid_search.best_estimator_
    best_train_pred = best_model.predict(X_train)
    best_test_pred = best_model.predict(X_test)
    return grid_search, best_train_pred, best_test_pred

def evaluate_classifier(grid_search, y_true_train, y_best_pred_train, y_true_test, y_best_pred_test, classifier_name):
    # Print the best model found
    print('Best Hyperparameters:', grid_search.best_params_)

    train_zero_one_loss = zero_one_loss(y_true_train, y_best_pred_train)
    train_report = classification_report(y_true_train, y_best_pred_train, digits=digits)

    test_zero_one_loss = zero_one_loss(y_true_test, y_best_pred_test)
    test_report = classification_report(y_true_test, y_best_pred_test, digits=digits)

    print(f'\nEvaluation Metrics for {classifier_name}:\n')

    print(f'(Best) Train Zero-One Loss: {train_zero_one_loss:.{digits}f}')
    print(f'(Best) Train Classification Report:\n{train_report}')

    print(f'(Best) Test Zero-One Loss: {test_zero_one_loss:.{digits}f}')
    print(f'(Best) Test Classification Report:\n{test_report}')

    # Print results for all combinations
    print('-' * 50)
    print('\nAll results:')
    for i in range(len(grid_search.cv_results_['params'])):
        print(f'Combination {i+1}:')
        print('Parameters:', grid_search.cv_results_['params'][i])
        print(f"Training Accuracy: {grid_search.cv_results_['mean_train_score'][i]:.{digits}f}")
        print(f"Validation Accuracy: {grid_search.cv_results_['mean_test_score'][i]:.{digits}f}")
        print('-' * 50)

def plot_results(grid_search, param_name, title, xlabel, log_scale=False, baseline_train_acc=None, baseline_test_acc=None):
    param_values = [0 if v is None else v for v in grid_search.cv_results_[f'param_{param_name}'].data] # in case of None value convert to 0
    param_values = np.array(param_values, dtype=float)
    train_accuracy = np.array(grid_search.cv_results_['mean_train_score']*100, dtype=float)
    vali_accuracy = np.array(grid_search.cv_results_['mean_test_score']*100, dtype=float)
    train_std = np.array(grid_search.cv_results_['std_train_score']*100, dtype=float)
    vali_std = np.array(grid_search.cv_results_['std_test_score']*100, dtype=float)

    plt.figure(figsize=(5, 4))
    plt.plot(param_values, train_accuracy, label='Train', color='tab:blue', alpha=0.6)
    plt.fill_between(param_values, train_accuracy - train_std, train_accuracy + train_std, color='tab:blue', alpha=0.25)
    if baseline_train_acc is not None:
        plt.axhline(y=baseline_train_acc, color='tab:blue', linestyle='--', label='Train Baseline')
    plt.plot(param_values, vali_accuracy, label='Validation', color='tab:red', alpha=0.6)
    plt.fill_between(param_values, vali_accuracy - vali_std, vali_accuracy + vali_std, color='tab:red', alpha=0.15)
    if baseline_test_acc is not None:
        plt.axhline(y=baseline_test_acc, color='tab:red', linestyle='--', label='Validation Baseline')
    
    plt.suptitle(title, fontsize=14, y=0.94)
    plt.xlabel(xlabel)
    if log_scale:
        plt.xscale('log')
    plt.ylabel('Mean Accuracy (%)')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Multi-nominal Logistic Regression
# We will test the performance both without- and with regularization.

# %% [markdown]
# #### Without Regularization

# %%
from sklearn.linear_model import LogisticRegression

lr_param = {'penalty': [None]}
lr_grid_search, lr_best_train_pred, lr_best_test_pred = hyperparameter_tuning(estimator=LogisticRegression(max_iter=10000, n_jobs=n_jobs),
                                                                              param_grid=lr_param,
                                                                              X_train=X_train,
                                                                              y_train=y_train,
                                                                              cv=cv,
                                                                              n_jobs=n_jobs,
                                                                              scoring=scoring)

evaluate_classifier(grid_search=lr_grid_search,
                    y_true_train=y_train,
                    y_best_pred_train=lr_best_train_pred,
                    y_true_test=y_test,
                    y_best_pred_test=lr_best_test_pred,
                    classifier_name='Logistic Regression')

# Store baseline accuracies for plotting
lr_baseline_train_accuracy = lr_grid_search.cv_results_['mean_train_score'][0]*100
lr_baseline_test_accuracy = lr_grid_search.cv_results_['mean_test_score'][0]*100
# Out:
# Best Hyperparameters: {'penalty': None}
#
# Evaluation Metrics for Logistic Regression:
#
# (Best) Train Zero-One Loss: 0.1497
# (Best) Train Classification Report:
#               precision    recall  f1-score   support
#
#          0.0     0.9621    0.9673    0.9647     17566
#          1.0     0.5584    0.4095    0.4725      3221
#          2.0     0.7779    0.8489    0.8118      8523
#          3.0     0.7314    0.5591    0.6337      1583
#          4.0     0.7034    0.7927    0.7454      2831
#
#     accuracy                         0.8503     33724
#    macro avg     0.7467    0.7155    0.7256     33724
# weighted avg     0.8445    0.8503    0.8451     33724
#
# (Best) Test Zero-One Loss: 0.0996
# (Best) Test Classification Report:
#               precision    recall  f1-score   support
#
#          0.0     0.9805    0.9815    0.9810      7579
#          1.0     0.4631    0.5265    0.4928       775
#          2.0     0.8953    0.8792    0.8872      3841
#          3.0     0.7560    0.6430    0.6949       395
#          4.0     0.7834    0.7918    0.7876      1311
#
#     accuracy                         0.9004     13901
#    macro avg     0.7756    0.7644    0.7687     13901
# weighted avg     0.9031    0.9004    0.9015     13901
#
# --------------------------------------------------
#
# All results:
# Combination 1:
# Parameters: {'penalty': None}
# Training Accuracy: 0.8535
# Validation Accuracy: 0.8349
# --------------------------------------------------

# %% [markdown]
# #### With Regularization

# %%
from sklearn.linear_model import LogisticRegression

lr_param = {'C': [0.00001, 0.0001, 0.001, 0.01, 0.1, 1, 10]}
lr_grid_search, lr_best_train_pred, lr_best_test_pred = hyperparameter_tuning(estimator=LogisticRegression(max_iter=10000, n_jobs=n_jobs),
                                                                              param_grid=lr_param,
                                                                              X_train=X_train,
                                                                              y_train=y_train,
                                                                              cv=cv,
                                                                              n_jobs=n_jobs,
                                                                              scoring=scoring)

evaluate_classifier(grid_search=lr_grid_search,
                    y_true_train=y_train,
                    y_best_pred_train=lr_best_train_pred,
                    y_true_test=y_test,
                    y_best_pred_test=lr_best_test_pred,
                    classifier_name='Logistic Regression')

plot_results(grid_search=lr_grid_search,
             param_name='C',
             title='Logistic Regression',
             xlabel='C (Regularization Strength)',
             log_scale=True,
             baseline_train_acc=lr_baseline_train_accuracy,
             baseline_test_acc=lr_baseline_test_accuracy)
# Out:
# Best Hyperparameters: {'C': 0.001}
#
# Evaluation Metrics for Logistic Regression:
#
# (Best) Train Zero-One Loss: 0.1555
# (Best) Train Classification Report:
#               precision    recall  f1-score   support
#
#          0.0     0.9584    0.9678    0.9631     17566
#          1.0     0.5446    0.3850    0.4511      3221
#          2.0     0.7664    0.8456    0.8040      8523
#          3.0     0.6975    0.5768    0.6314      1583
#          4.0     0.7070    0.7485    0.7272      2831
#
#     accuracy                         0.8445     33724
#    macro avg     0.7348    0.7047    0.7154     33724
# weighted avg     0.8370    0.8445    0.8386     33724
#
# (Best) Test Zero-One Loss: 0.0963
# (Best) Test Classification Report:
#               precision    recall  f1-score   support
#
#          0.0     0.9799    0.9827    0.9813      7579
#          1.0     0.4698    0.5226    0.4948       775
#          2.0     0.9037    0.8823    0.8929      3841
#          3.0     0.7179    0.7215    0.7197       395
#          4.0     0.8017    0.7895    0.7955      1311
#
#     accuracy                         0.9037     13901
#    macro avg     0.7746    0.7797    0.7768     13901
# weighted avg     0.9062    0.9037    0.9048     13901
#
# --------------------------------------------------
#
# All results:
# Combination 1:
# Parameters: {'C': 1e-05}
# Training Accuracy: 0.6991
# Validation Accuracy: 0.6977
# --------------------------------------------------
# Combination 2:
# Parameters: {'C': 0.0001}
# Training Accuracy: 0.8209
# Validation Accuracy: 0.8186
# --------------------------------------------------
# Combination 3:
# Parameters: {'C': 0.001}
# Training Accuracy: 0.8450
# Validation Accuracy: 0.8402
# --------------------------------------------------
# Combination 4:
# Parameters: {'C': 0.01}
# Training Accuracy: 0.8490
# Validation Accuracy: 0.8401
# --------------------------------------------------
# Combination 5:
# Parameters: {'C': 0.1}
# Training Accuracy: 0.8517
# Validation Accuracy: 0.8381
# --------------------------------------------------
# Combination 6:
# Parameters: {'C': 1}
# Training Accuracy: 0.8533
# Validation Accuracy: 0.8365
# --------------------------------------------------
# Combination 7:
# Parameters: {'C': 10}
# Training Accuracy: 0.8535
# Validation Accuracy: 0.8353
# --------------------------------------------------

# %% [markdown]
# ### Random Forests

# %%
from sklearn.ensemble import RandomForestClassifier

# Hyperparameter tuning
rf_param = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, *range(1, 16)],  # * unpack the range into the list
}

rf_grid_search, rf_best_train_pred, rf_best_test_pred = hyperparameter_tuning(estimator=RandomForestClassifier(n_jobs=n_jobs),
                                                                              param_grid=rf_param,
                                                                              X_train=X_train,
                                                                              y_train=y_train,
                                                                              cv=cv,
                                                                              n_jobs=n_jobs,
                                                                              scoring=scoring)

evaluate_classifier(grid_search=rf_grid_search,
                    y_true_train=y_train,
                    y_best_pred_train=rf_best_train_pred,
                    y_true_test=y_test,
                    y_best_pred_test=rf_best_test_pred,
                    classifier_name='Random Forest')

plot_results(grid_search=rf_grid_search,
             param_name='max_depth',
             title='Random Forest',
             xlabel='Max Depth')
# Out:
# Best Hyperparameters: {'max_depth': 4, 'n_estimators': 200}
#
# Evaluation Metrics for Random Forest:
#
# (Best) Train Zero-One Loss: 0.1520
# (Best) Train Classification Report:
#               precision    recall  f1-score   support
#
#          0.0     0.9568    0.9704    0.9635     17566
#          1.0     0.5536    0.4170    0.4757      3221
#          2.0     0.7715    0.8528    0.8101      8523
#          3.0     0.7513    0.5287    0.6207      1583
#          4.0     0.7140    0.7436    0.7285      2831
#
#     accuracy                         0.8480     33724
#    macro avg     0.7495    0.7025    0.7197     33724
# weighted avg     0.8414    0.8480    0.8423     33724
#
# (Best) Test Zero-One Loss: 0.0989
# (Best) Test Classification Report:
#               precision    recall  f1-score   support
#
#          0.0     0.9749    0.9852    0.9800      7579
#          1.0     0.4581    0.5226    0.4882       775
#          2.0     0.9015    0.8815    0.8914      3841
#          3.0     0.7493    0.6582    0.7008       395
#          4.0     0.8032    0.7689    0.7857      1311
#
#     accuracy                         0.9011     13901
#    macro avg     0.7774    0.7633    0.7692     13901
# weighted avg     0.9032    0.9011    0.9019     13901
#
# --------------------------------------------------
#
# All results:
# Combination 1:
# Parameters: {'max_depth': None, 'n_estimators': 50}
# Training Accuracy: 0.9997
# Validation Accuracy: 0.8201
# --------------------------------------------------
# Combination 2:
# Parameters: {'max_depth': None, 'n_estimators': 100}
# Training Accuracy: 1.0000
# Validation Accuracy: 0.8235
# --------------------------------------------------
# Combination 3:
# Parameters: {'max_depth': None, 'n_estimators': 200}
# Training Accuracy: 1.0000
# Validation Accuracy: 0.8250
# --------------------------------------------------
# Combination 4:
# Parameters: {'max_depth': 1, 'n_estimators': 50}
# Training Accuracy: 0.7578
# Validation Accuracy: 0.7578
# --------------------------------------------------
# Combination 5:
# Parameters: {'max_depth': 1, 'n_estimators': 100}
# Training Accuracy: 0.7591
# Validation Accuracy: 0.7579
# --------------------------------------------------
# Combination 6:
# Parameters: {'max_depth': 1, 'n_estimators': 200}
# Training Accuracy: 0.7593
# Validation Accuracy: 0.7586
# --------------------------------------------------
# Combination 7:
# Parameters: {'max_depth': 2, 'n_estimators': 50}
# Training Accuracy: 0.8103
# Validation Accuracy: 0.8080
# --------------------------------------------------
# Combination 8:
# Parameters: {'max_depth': 2, 'n_estimators': 100}
# Training Accuracy: 0.8169
# Validation Accuracy: 0.8122
# --------------------------------------------------
# Combination 9:
# Parameters: {'max_depth': 2, 'n_estimators': 200}
# Training Accuracy: 0.8165
# Validation Accuracy: 0.8124
# --------------------------------------------------
# Combination 10:
# Parameters: {'max_depth': 3, 'n_estimators': 50}
# Training Accuracy: 0.8477
# Validation Accuracy: 0.8366
# --------------------------------------------------
# Combination 11:
# Parameters: {'max_depth': 3, 'n_estimators': 100}
# Training Accuracy: 0.8482
# Validation Accuracy: 0.8374
# --------------------------------------------------
# Combination 12:
# Parameters: {'max_depth': 3, 'n_estimators': 200}
# Training Accuracy: 0.8480
# Validation Accuracy: 0.8367
# --------------------------------------------------
# Combination 13:
# Parameters: {'max_depth': 4, 'n_estimators': 50}
# Training Accuracy: 0.8511
# Validation Accuracy: 0.8374
# --------------------------------------------------
# Combination 14:
# Parameters: {'max_depth': 4, 'n_estimators': 100}
# Training Accuracy: 0.8506
# Validation Accuracy: 0.8364
# --------------------------------------------------
# Combination 15:
# Parameters: {'max_depth': 4, 'n_estimators': 200}
# Training Accuracy: 0.8509
# Validation Accuracy: 0.8380
# --------------------------------------------------
# Combination 16:
# Parameters: {'max_depth': 5, 'n_estimators': 50}
# Training Accuracy: 0.8554
# Validation Accuracy: 0.8373
# --------------------------------------------------
# Combination 17:
# Parameters: {'max_depth': 5, 'n_estimators': 100}
# Training Accuracy: 0.8550
# Validation Accuracy: 0.8379
# --------------------------------------------------
# Combination 18:
# Parameters: {'max_depth': 5, 'n_estimators': 200}
# Training Accuracy: 0.8554
# Validation Accuracy: 0.8374
# --------------------------------------------------
# Combination 19:
# Parameters: {'max_depth': 6, 'n_estimators': 50}
# Training Accuracy: 0.8612
# Validation Accuracy: 0.8357
# --------------------------------------------------
# Combination 20:
# Parameters: {'max_depth': 6, 'n_estimators': 100}
# Training Accuracy: 0.8611
# Validation Accuracy: 0.8364
# --------------------------------------------------
# Combination 21:
# Parameters: {'max_depth': 6, 'n_estimators': 200}
# Training Accuracy: 0.8614
# Validation Accuracy: 0.8370
# --------------------------------------------------
# Combination 22:
# Parameters: {'max_depth': 7, 'n_estimators': 50}
# Training Accuracy: 0.8686
# Validation Accuracy: 0.8344
# --------------------------------------------------
# Combination 23:
# Parameters: {'max_depth': 7, 'n_estimators': 100}
# Training Accuracy: 0.8686
# Validation Accuracy: 0.8347
# --------------------------------------------------
# Combination 24:
# Parameters: {'max_depth': 7, 'n_estimators': 200}
# Training Accuracy: 0.8691
# Validation Accuracy: 0.8354
# --------------------------------------------------
# Combination 25:
# Parameters: {'max_depth': 8, 'n_estimators': 50}
# Training Accuracy: 0.8781
# Validation Accuracy: 0.8341
# --------------------------------------------------
# Combination 26:
# Parameters: {'max_depth': 8, 'n_estimators': 100}
# Training Accuracy: 0.8788
# Validation Accuracy: 0.8341
# --------------------------------------------------
# Combination 27:
# Parameters: {'max_depth': 8, 'n_estimators': 200}
# Training Accuracy: 0.8786
# Validation Accuracy: 0.8336
# --------------------------------------------------
# Combination 28:
# Parameters: {'max_depth': 9, 'n_estimators': 50}
# Training Accuracy: 0.8912
# Validation Accuracy: 0.8317
# --------------------------------------------------
# Combination 29:
# Parameters: {'max_depth': 9, 'n_estimators': 100}
# Training Accuracy: 0.8911
# Validation Accuracy: 0.8318
# --------------------------------------------------
# Combination 30:
# Parameters: {'max_depth': 9, 'n_estimators': 200}
# Training Accuracy: 0.8915
# Validation Accuracy: 0.8326
# --------------------------------------------------
# Combination 31:
# Parameters: {'max_depth': 10, 'n_estimators': 50}
# Training Accuracy: 0.9064
# Validation Accuracy: 0.8303
# --------------------------------------------------
# Combination 32:
# Parameters: {'max_depth': 10, 'n_estimators': 100}
# Training Accuracy: 0.9067
# Validation Accuracy: 0.8307
# --------------------------------------------------
# Combination 33:
# Parameters: {'max_depth': 10, 'n_estimators': 200}
# Training Accuracy: 0.9072
# Validation Accuracy: 0.8316
# --------------------------------------------------
# Combination 34:
# Parameters: {'max_depth': 11, 'n_estimators': 50}
# Training Accuracy: 0.9215
# Validation Accuracy: 0.8289
# --------------------------------------------------
# Combination 35:
# Parameters: {'max_depth': 11, 'n_estimators': 100}
# Training Accuracy: 0.9220
# Validation Accuracy: 0.8303
# --------------------------------------------------
# Combination 36:
# Parameters: {'max_depth': 11, 'n_estimators': 200}
# Training Accuracy: 0.9233
# Validation Accuracy: 0.8306
# --------------------------------------------------
# Combination 37:
# Parameters: {'max_depth': 12, 'n_estimators': 50}
# Training Accuracy: 0.9379
# Validation Accuracy: 0.8278
# --------------------------------------------------
# Combination 38:
# Parameters: {'max_depth': 12, 'n_estimators': 100}
# Training Accuracy: 0.9380
# Validation Accuracy: 0.8294
# --------------------------------------------------
# Combination 39:
# Parameters: {'max_depth': 12, 'n_estimators': 200}
# Training Accuracy: 0.9386
# Validation Accuracy: 0.8288
# --------------------------------------------------
# Combination 40:
# Parameters: {'max_depth': 13, 'n_estimators': 50}
# Training Accuracy: 0.9514
# Validation Accuracy: 0.8272
# --------------------------------------------------
# Combination 41:
# Parameters: {'max_depth': 13, 'n_estimators': 100}
# Training Accuracy: 0.9521
# Validation Accuracy: 0.8278
# --------------------------------------------------
# Combination 42:
# Parameters: {'max_depth': 13, 'n_estimators': 200}
# Training Accuracy: 0.9526
# Validation Accuracy: 0.8283
# --------------------------------------------------
# Combination 43:
# Parameters: {'max_depth': 14, 'n_estimators': 50}
# Training Accuracy: 0.9637
# Validation Accuracy: 0.8260
# --------------------------------------------------
# Combination 44:
# Parameters: {'max_depth': 14, 'n_estimators': 100}
# Training Accuracy: 0.9640
# Validation Accuracy: 0.8271
# --------------------------------------------------
# Combination 45:
# Parameters: {'max_depth': 14, 'n_estimators': 200}
# Training Accuracy: 0.9647
# Validation Accuracy: 0.8270
# --------------------------------------------------
# Combination 46:
# Parameters: {'max_depth': 15, 'n_estimators': 50}
# Training Accuracy: 0.9725
# Validation Accuracy: 0.8233
# --------------------------------------------------
# Combination 47:
# Parameters: {'max_depth': 15, 'n_estimators': 100}
# Training Accuracy: 0.9740
# Validation Accuracy: 0.8259
# --------------------------------------------------
# Combination 48:
# Parameters: {'max_depth': 15, 'n_estimators': 200}
# Training Accuracy: 0.9743
# Validation Accuracy: 0.8260
# --------------------------------------------------

# %% [markdown]
# ### k-Nearest-Neighbor

# %%
from sklearn.neighbors import KNeighborsClassifier

# Define the parameter grid
# As a rule of thumb the number of neighbors in a set should be sqrt(n) where n is the number of samples in the set: https://quantdev.ssri.psu.edu/sites/qdev/files/kNN_tutorial.html
# K-neighbors should be an odd value in KNN to avoid ties at decision boundaries
# where majority voting occurs. Using odd numbers helps prevent ties.
knn_param = {'n_neighbors': range(1, 150, 2)}  # Considering 1 to 149 neighbors (odd numbers)

knn_grid_search, knn_best_train_pred, knn_best_test_pred = hyperparameter_tuning(estimator=KNeighborsClassifier(n_jobs=n_jobs),
                                                                              param_grid=knn_param,
                                                                              X_train=X_train,
                                                                              y_train=y_train,
                                                                              cv=cv,
                                                                              n_jobs=n_jobs,
                                                                              scoring=scoring)

evaluate_classifier(grid_search=knn_grid_search,
                    y_true_train=y_train,
                    y_best_pred_train=knn_best_train_pred,
                    y_true_test=y_test,
                    y_best_pred_test=knn_best_test_pred,
                    classifier_name='K-Nearest Neighbors')

plot_results(grid_search=knn_grid_search,
             param_name='n_neighbors',
             title='K-Nearest Neighbors',
             xlabel='Number of Neighbors')
# Out:
# Best Hyperparameters: {'n_neighbors': 125}
#
# Evaluation Metrics for K-Nearest Neighbors:
#
# (Best) Train Zero-One Loss: 0.1487
# (Best) Train Classification Report:
#               precision    recall  f1-score   support
#
#          0.0     0.9614    0.9693    0.9653     17566
#          1.0     0.5713    0.4256    0.4878      3221
#          2.0     0.7791    0.8508    0.8133      8523
#          3.0     0.7543    0.5294    0.6221      1583
#          4.0     0.6955    0.7849    0.7375      2831
#
#     accuracy                         0.8513     33724
#    macro avg     0.7523    0.7120    0.7252     33724
# weighted avg     0.8460    0.8513    0.8461     33724
#
# (Best) Test Zero-One Loss: 0.0962
# (Best) Test Classification Report:
#               precision    recall  f1-score   support
#
#          0.0     0.9795    0.9834    0.9814      7579
#          1.0     0.4748    0.5355    0.5033       775
#          2.0     0.9060    0.8808    0.8932      3841
#          3.0     0.7645    0.6658    0.7118       395
#          4.0     0.7836    0.8009    0.7922      1311
#
#     accuracy                         0.9038     13901
#    macro avg     0.7817    0.7733    0.7764     13901
# weighted avg     0.9065    0.9038    0.9049     13901
#
# --------------------------------------------------
#
# All results:
# Combination 1:
# Parameters: {'n_neighbors': 1}
# Training Accuracy: 1.0000
# Validation Accuracy: 0.7796
# --------------------------------------------------
# Combination 2:
# Parameters: {'n_neighbors': 3}
# Training Accuracy: 0.9000
# Validation Accuracy: 0.8014
# --------------------------------------------------
# Combination 3:
# Parameters: {'n_neighbors': 5}
# Training Accuracy: 0.8837
# Validation Accuracy: 0.8141
# --------------------------------------------------
# Combination 4:
# Parameters: {'n_neighbors': 7}
# Training Accuracy: 0.8754
# Validation Accuracy: 0.8200
# --------------------------------------------------
# Combination 5:
# Parameters: {'n_neighbors': 9}
# Training Accuracy: 0.8713
# Validation Accuracy: 0.8227
# --------------------------------------------------
# Combination 6:
# Parameters: {'n_neighbors': 11}
# Training Accuracy: 0.8681
# Validation Accuracy: 0.8250
# --------------------------------------------------
# Combination 7:
# Parameters: {'n_neighbors': 13}
# Training Accuracy: 0.8655
# Validation Accuracy: 0.8266
# --------------------------------------------------
# Combination 8:
# Parameters: {'n_neighbors': 15}
# Training Accuracy: 0.8634
# Validation Accuracy: 0.8287
# --------------------------------------------------
# Combination 9:
# Parameters: {'n_neighbors': 17}
# Training Accuracy: 0.8625
# Validation Accuracy: 0.8306
# --------------------------------------------------
# Combination 10:
# Parameters: {'n_neighbors': 19}
# Training Accuracy: 0.8618
# Validation Accuracy: 0.8312
# --------------------------------------------------
# Combination 11:
# Parameters: {'n_neighbors': 21}
# Training Accuracy: 0.8616
# Validation Accuracy: 0.8310
# --------------------------------------------------
# Combination 12:
# Parameters: {'n_neighbors': 23}
# Training Accuracy: 0.8606
# Validation Accuracy: 0.8313
# --------------------------------------------------
# Combination 13:
# Parameters: {'n_neighbors': 25}
# Training Accuracy: 0.8610
# Validation Accuracy: 0.8314
# --------------------------------------------------
# Combination 14:
# Parameters: {'n_neighbors': 27}
# Training Accuracy: 0.8600
# Validation Accuracy: 0.8320
# --------------------------------------------------
# Combination 15:
# Parameters: {'n_neighbors': 29}
# Training Accuracy: 0.8596
# Validation Accuracy: 0.8318
# --------------------------------------------------
# Combination 16:
# Parameters: {'n_neighbors': 31}
# Training Accuracy: 0.8593
# Validation Accuracy: 0.8324
# --------------------------------------------------
# Combination 17:
# Parameters: {'n_neighbors': 33}
# Training Accuracy: 0.8587
# Validation Accuracy: 0.8327
# --------------------------------------------------
# Combination 18:
# Parameters: {'n_neighbors': 35}
# Training Accuracy: 0.8578
# Validation Accuracy: 0.8327
# --------------------------------------------------
# Combination 19:
# Parameters: {'n_neighbors': 37}
# Training Accuracy: 0.8577
# Validation Accuracy: 0.8332
# --------------------------------------------------
# Combination 20:
# Parameters: {'n_neighbors': 39}
# Training Accuracy: 0.8575
# Validation Accuracy: 0.8327
# --------------------------------------------------
# Combination 21:
# Parameters: {'n_neighbors': 41}
# Training Accuracy: 0.8567
# Validation Accuracy: 0.8326
# --------------------------------------------------
# Combination 22:
# Parameters: {'n_neighbors': 43}
# Training Accuracy: 0.8563
# Validation Accuracy: 0.8330
# --------------------------------------------------
# Combination 23:
# Parameters: {'n_neighbors': 45}
# Training Accuracy: 0.8564
# Validation Accuracy: 0.8332
# --------------------------------------------------
# Combination 24:
# Parameters: {'n_neighbors': 47}
# Training Accuracy: 0.8563
# Validation Accuracy: 0.8332
# --------------------------------------------------
# Combination 25:
# Parameters: {'n_neighbors': 49}
# Training Accuracy: 0.8563
# Validation Accuracy: 0.8333
# --------------------------------------------------
# Combination 26:
# Parameters: {'n_neighbors': 51}
# Training Accuracy: 0.8559
# Validation Accuracy: 0.8339
# --------------------------------------------------
# Combination 27:
# Parameters: {'n_neighbors': 53}
# Training Accuracy: 0.8552
# Validation Accuracy: 0.8335
# --------------------------------------------------
# Combination 28:
# Parameters: {'n_neighbors': 55}
# Training Accuracy: 0.8557
# Validation Accuracy: 0.8335
# --------------------------------------------------
# Combination 29:
# Parameters: {'n_neighbors': 57}
# Training Accuracy: 0.8553
# Validation Accuracy: 0.8337
# --------------------------------------------------
# Combination 30:
# Parameters: {'n_neighbors': 59}
# Training Accuracy: 0.8553
# Validation Accuracy: 0.8337
# --------------------------------------------------
# Combination 31:
# Parameters: {'n_neighbors': 61}
# Training Accuracy: 0.8550
# Validation Accuracy: 0.8332
# --------------------------------------------------
# Combination 32:
# Parameters: {'n_neighbors': 63}
# Training Accuracy: 0.8553
# Validation Accuracy: 0.8335
# --------------------------------------------------
# Combination 33:
# Parameters: {'n_neighbors': 65}
# Training Accuracy: 0.8549
# Validation Accuracy: 0.8342
# --------------------------------------------------
# Combination 34:
# Parameters: {'n_neighbors': 67}
# Training Accuracy: 0.8550
# Validation Accuracy: 0.8340
# --------------------------------------------------
# Combination 35:
# Parameters: {'n_neighbors': 69}
# Training Accuracy: 0.8549
# Validation Accuracy: 0.8343
# --------------------------------------------------
# Combination 36:
# Parameters: {'n_neighbors': 71}
# Training Accuracy: 0.8548
# Validation Accuracy: 0.8348
# --------------------------------------------------
# Combination 37:
# Parameters: {'n_neighbors': 73}
# Training Accuracy: 0.8547
# Validation Accuracy: 0.8350
# --------------------------------------------------
# Combination 38:
# Parameters: {'n_neighbors': 75}
# Training Accuracy: 0.8543
# Validation Accuracy: 0.8348
# --------------------------------------------------
# Combination 39:
# Parameters: {'n_neighbors': 77}
# Training Accuracy: 0.8541
# Validation Accuracy: 0.8351
# --------------------------------------------------
# Combination 40:
# Parameters: {'n_neighbors': 79}
# Training Accuracy: 0.8542
# Validation Accuracy: 0.8349
# --------------------------------------------------
# Combination 41:
# Parameters: {'n_neighbors': 81}
# Training Accuracy: 0.8539
# Validation Accuracy: 0.8351
# --------------------------------------------------
# Combination 42:
# Parameters: {'n_neighbors': 83}
# Training Accuracy: 0.8536
# Validation Accuracy: 0.8349
# --------------------------------------------------
# Combination 43:
# Parameters: {'n_neighbors': 85}
# Training Accuracy: 0.8536
# Validation Accuracy: 0.8353
# --------------------------------------------------
# Combination 44:
# Parameters: {'n_neighbors': 87}
# Training Accuracy: 0.8539
# Validation Accuracy: 0.8353
# --------------------------------------------------
# Combination 45:
# Parameters: {'n_neighbors': 89}
# Training Accuracy: 0.8537
# Validation Accuracy: 0.8355
# --------------------------------------------------
# Combination 46:
# Parameters: {'n_neighbors': 91}
# Training Accuracy: 0.8536
# Validation Accuracy: 0.8357
# --------------------------------------------------
# Combination 47:
# Parameters: {'n_neighbors': 93}
# Training Accuracy: 0.8532
# Validation Accuracy: 0.8356
# --------------------------------------------------
# Combination 48:
# Parameters: {'n_neighbors': 95}
# Training Accuracy: 0.8531
# Validation Accuracy: 0.8360
# --------------------------------------------------
# Combination 49:
# Parameters: {'n_neighbors': 97}
# Training Accuracy: 0.8533
# Validation Accuracy: 0.8362
# --------------------------------------------------
# Combination 50:
# Parameters: {'n_neighbors': 99}
# Training Accuracy: 0.8533
# Validation Accuracy: 0.8358
# --------------------------------------------------
# Combination 51:
# Parameters: {'n_neighbors': 101}
# Training Accuracy: 0.8530
# Validation Accuracy: 0.8359
# --------------------------------------------------
# Combination 52:
# Parameters: {'n_neighbors': 103}
# Training Accuracy: 0.8530
# Validation Accuracy: 0.8358
# --------------------------------------------------
# Combination 53:
# Parameters: {'n_neighbors': 105}
# Training Accuracy: 0.8531
# Validation Accuracy: 0.8361
# --------------------------------------------------
# Combination 54:
# Parameters: {'n_neighbors': 107}
# Training Accuracy: 0.8532
# Validation Accuracy: 0.8364
# --------------------------------------------------
# Combination 55:
# Parameters: {'n_neighbors': 109}
# Training Accuracy: 0.8526
# Validation Accuracy: 0.8364
# --------------------------------------------------
# Combination 56:
# Parameters: {'n_neighbors': 111}
# Training Accuracy: 0.8527
# Validation Accuracy: 0.8361
# --------------------------------------------------
# Combination 57:
# Parameters: {'n_neighbors': 113}
# Training Accuracy: 0.8526
# Validation Accuracy: 0.8359
# --------------------------------------------------
# Combination 58:
# Parameters: {'n_neighbors': 115}
# Training Accuracy: 0.8527
# Validation Accuracy: 0.8361
# --------------------------------------------------
# Combination 59:
# Parameters: {'n_neighbors': 117}
# Training Accuracy: 0.8523
# Validation Accuracy: 0.8360
# --------------------------------------------------
# Combination 60:
# Parameters: {'n_neighbors': 119}
# Training Accuracy: 0.8524
# Validation Accuracy: 0.8358
# --------------------------------------------------
# Combination 61:
# Parameters: {'n_neighbors': 121}
# Training Accuracy: 0.8524
# Validation Accuracy: 0.8359
# --------------------------------------------------
# Combination 62:
# Parameters: {'n_neighbors': 123}
# Training Accuracy: 0.8524
# Validation Accuracy: 0.8364
# --------------------------------------------------
# Combination 63:
# Parameters: {'n_neighbors': 125}
# Training Accuracy: 0.8524
# Validation Accuracy: 0.8365
# --------------------------------------------------
# Combination 64:
# Parameters: {'n_neighbors': 127}
# Training Accuracy: 0.8525
# Validation Accuracy: 0.8361
# --------------------------------------------------
# Combination 65:
# Parameters: {'n_neighbors': 129}
# Training Accuracy: 0.8525
# Validation Accuracy: 0.8363
# --------------------------------------------------
# Combination 66:
# Parameters: {'n_neighbors': 131}
# Training Accuracy: 0.8523
# Validation Accuracy: 0.8364
# --------------------------------------------------
# Combination 67:
# Parameters: {'n_neighbors': 133}
# Training Accuracy: 0.8520
# Validation Accuracy: 0.8365
# --------------------------------------------------
# Combination 68:
# Parameters: {'n_neighbors': 135}
# Training Accuracy: 0.8517
# Validation Accuracy: 0.8365
# --------------------------------------------------
# Combination 69:
# Parameters: {'n_neighbors': 137}
# Training Accuracy: 0.8520
# Validation Accuracy: 0.8363
# --------------------------------------------------
# Combination 70:
# Parameters: {'n_neighbors': 139}
# Training Accuracy: 0.8518
# Validation Accuracy: 0.8363
# --------------------------------------------------
# Combination 71:
# Parameters: {'n_neighbors': 141}
# Training Accuracy: 0.8518
# Validation Accuracy: 0.8362
# --------------------------------------------------
# Combination 72:
# Parameters: {'n_neighbors': 143}
# Training Accuracy: 0.8519
# Validation Accuracy: 0.8362
# --------------------------------------------------
# Combination 73:
# Parameters: {'n_neighbors': 145}
# Training Accuracy: 0.8512
# Validation Accuracy: 0.8363
# --------------------------------------------------
# Combination 74:
# Parameters: {'n_neighbors': 147}
# Training Accuracy: 0.8515
# Validation Accuracy: 0.8362
# --------------------------------------------------
# Combination 75:
# Parameters: {'n_neighbors': 149}
# Training Accuracy: 0.8511
# Validation Accuracy: 0.8360
# --------------------------------------------------

# %% [markdown]
# # 2. Invariance and normalization (30 points)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Original data
data = {
    'Mr. Good':     np.array([47, 35]),
    'Mr. Bad':      np.array([22, 40]),
    'Mr. Unknown':  np.array([21, 36])
}

# Calculate means
mean_x = np.mean([data['Mr. Good'][0], data['Mr. Bad'][0]])
mean_y = np.mean([data['Mr. Good'][1], data['Mr. Bad'][1]])

print(f'Mean of age: {mean_x}')
print(f'Mean of income: {mean_y}\n')

# Center the data (zero mean)
centered_data = {key: value - [mean_x, mean_y] for key, value in data.items()}

for key, value in centered_data.items():
    print(f'Centered coordinates for {key}: {value}')

# Calculate variances
var_x = np.var([centered_data['Mr. Good'][0], centered_data['Mr. Bad'][0]])
var_y = np.var([centered_data['Mr. Good'][1], centered_data['Mr. Bad'][1]])

print(f'\nVariance of age: {var_x}')
print(f'Variance of income: {var_y}')

# Calculate standard deviations
std_x = np.sqrt(var_x)
std_y = np.sqrt(var_y)

print(f'\nStandard deviation of age: {std_x}')
print(f'Standard deviation of income: {std_y}\n')

# Normalize the data (variance one)
normalized_data = {key: [value[0]/std_x, value[1]/std_y] for key, value in centered_data.items()}

for key, value in normalized_data.items():
    print(f'Normalized coordinates for {key}: {value}')

# Plotting
fig, ax = plt.subplots(1, 2, figsize=(6, 3))

# Original data plot
for key, value in data.items():
    ax[0].scatter(value[0], value[1], label=key, alpha=0.6)
ax[0].set_title('Original data')
ax[0].set_xlabel('Age (years)')
ax[0].set_ylabel('Income (thousands of $)')
ax[0].grid(True)
ax[0].set_xlim(0, 50)
ax[0].set_ylim(0, 50)

# Normalized data plot
for key, value in normalized_data.items():
    ax[1].scatter(value[0], value[1], label=key, alpha=0.6)
ax[1].set_title('Normalized data')
ax[1].set_xlabel('Age (normalized)')
ax[1].set_ylabel('Income (normalized)')
ax[1].grid(True)

# Add a single legend for the entire figure
handles, labels = ax[0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper center', bbox_to_anchor=(0.5, 0.04), ncol=3)
plt.suptitle('Invariance and Normalization', fontsize=14, y=0.94)
plt.tight_layout()
plt.show()
# Out:
# Mean of age: 34.5
# Mean of income: 37.5
#
# Centered coordinates for Mr. Good: [12.5 -2.5]
# Centered coordinates for Mr. Bad: [-12.5   2.5]
# Centered coordinates for Mr. Unknown: [-13.5  -1.5]
#
# Variance of age: 156.25
# Variance of income: 6.25
#
# Standard deviation of age: 12.5
# Standard deviation of income: 2.5
#
# Normalized coordinates for Mr. Good: [1.0, -1.0]
# Normalized coordinates for Mr. Bad: [-1.0, 1.0]
# Normalized coordinates for Mr. Unknown: [-1.08, -0.6]

# %% [markdown]
# # 3. Differentiable programming (35 points)

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch

# Parameter affecting the shape of the quadratic function
p_f = 0.5

# Range for plotting the function
r = 1.

# Quadratic function definition
def f(x, y):
    """Compute the value of the function for given x and y."""
    return (p_f*x)**2 + y**2 + p_f*x*y

def gradient_descent_plot(optimizer_type, p_x, p_y, r, eta, n_iter, ax):
    """
    Plot the contour of the function and the gradient descent path on the given axis.
    
    Parameters:
    - p_x, p_y: Lists containing x and y coordinates of the gradient descent path.
    - r: Range for plotting.
    - n_iter: Number of iterations.
    - ax: Axis on which to plot.
    """

    # Generate meshgrid for contour plot
    x = np.linspace(-r, r, 50)
    y = np.linspace(-r, r, 50)
    X, Y = np.meshgrid(x, y)
    Z = f(X, Y)
    
    # Draw contour lines and fill on the given axis
    contours = ax.contour(X, Y, Z, [0.01, 0.05, 0.1, 0.5, 1.], colors='grey')
    ax.clabel(contours, inline=True, fontsize=6)
    ax.imshow(Z, extent=[-r, r, -r, r], origin='lower', cmap='RdGy', alpha=0.5)

    # Mark the optimum point on the given axis
    ax.plot(0, 0, 'x', c='k')

    # Plot arrows showing the gradient descent path on the given axis
    for i in range(n_iter):
        ax.arrow(p_x[i], p_y[i], p_x[i+1]-p_x[i], p_y[i+1]-p_y[i], width=.005, head_width=.045, head_length=.025, length_includes_head=True, fc='b', ec='b', zorder=10)
    
    # Set title for the given axis
    ax.set_title(f'{optimizer_type} (η={eta} and {n_iter} iterations)', fontsize=14)
    ax.grid(True)

def perform_gradient_descent(optimizer_type, eta, n_iter, r, ax):
    """
    Perform gradient descent optimization and store the path.
    
    Parameters:
    - optimizer_type: Type of optimizer to use ('SGD' or 'Adam').
    - eta: Learning rate.
    - n_iter: Number of iterations.
    - r: Range for initial point.
    """
    # Initialize starting point
    x = torch.ones(1, requires_grad=True)
    y = torch.ones(1, requires_grad=True)
    with torch.no_grad():
        x *= 0.9*r
        y *= 0.8*r

    # Lists to store path of gradient descent
    p_x = [x.item()]
    p_y = [y.item()]

    # Choose optimizer based on input
    if optimizer_type == 'SGD':
        optimizer = torch.optim.SGD([x, y], lr=eta)
    elif optimizer_type == 'Adam':
        optimizer = torch.optim.Adam([x, y], lr=eta)
    else:
        raise ValueError('Unsupported optimizer type')

    # Gradient descent loop
    for i in range(n_iter):
        optimizer.zero_grad()
        f(x, y).backward()
        optimizer.step()
        p_x.append(x.item())
        p_y.append(y.item())

    # Plot the results of gradient descent
    gradient_descent_plot(optimizer_type, p_x, p_y, r, eta, n_iter, ax)

def gradient_descent_grid_search(optimizer_type, learning_rates, iterations, r):
    best_eta = None
    best_n_iter = None
    best_value = float('inf')
    
    print('-' * 50)
    print(f'All results for {optimizer_type}:')
    print('-' * 50)
    
    combination_count = 1
    for eta in learning_rates:
        for n_iter in iterations:
            x = torch.ones(1, requires_grad=True)
            y = torch.ones(1, requires_grad=True)
            with torch.no_grad():
                x *= 0.9*r
                y *= 0.8*r
            if optimizer_type == 'SGD':
                optimizer = torch.optim.SGD([x, y], lr=eta)
            elif optimizer_type == 'Adam':
                optimizer = torch.optim.Adam([x, y], lr=eta)
            for _ in range(n_iter):
                optimizer.zero_grad()
                f(x, y).backward()
                optimizer.step()
            value = f(x, y).item()
            
            # Print the results for this combination
            print(f'Combination {combination_count}:')
            print(f'Learning Rate: {eta}, Iterations: {n_iter}')
            print(f'Final value of function: {value}')
            print('-' * 50)
            
            if value < best_value:
                best_value = value
                best_eta = eta
                best_n_iter = n_iter
                
            combination_count += 1

    print(f'Best Combination:')
    print(f'Learning Rate: {best_eta}, Iterations: {best_n_iter}')
    print(f'Final value of function: {best_value}')
    print('-' * 50)
                
    return best_eta, best_n_iter, best_value

# Define a range of learning rates and iterations to search over
learning_rates = [0.1, 0.3, 0.5, 0.7, 0.9]
iterations = [5, 10, 15, 20, 25]

# Find the best parameters for SGD
best_eta_sgd, best_n_iter_sgd, best_value_sgd = gradient_descent_grid_search('SGD', learning_rates, iterations, r)

# Find the best parameters for Adam
best_eta_adam, best_n_iter_adam, best_value_adam = gradient_descent_grid_search('Adam', learning_rates, iterations, r)

# Plot using the best parameters
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))
perform_gradient_descent('SGD', best_eta_sgd, best_n_iter_sgd, r, ax=ax1)
perform_gradient_descent('Adam', best_eta_adam, best_n_iter_adam, r, ax=ax2)

plt.suptitle('Gradient Descent Optimization', fontsize=16, y=1)
plt.tight_layout()
plt.show()
# Out:
# --------------------------------------------------
# All results for SGD:
# --------------------------------------------------
# Combination 1:
# Learning Rate: 0.1, Iterations: 5
# Final value of function: 0.1489834040403366
# --------------------------------------------------
# Combination 2:
# Learning Rate: 0.1, Iterations: 10
# Final value of function: 0.04289386048913002
# --------------------------------------------------
# Combination 3:
# Learning Rate: 0.1, Iterations: 15
# Final value of function: 0.024618230760097504
# --------------------------------------------------
# Combination 4:
# Learning Rate: 0.1, Iterations: 20
# Final value of function: 0.01677996665239334
# --------------------------------------------------
# Combination 5:
# Learning Rate: 0.1, Iterations: 25
# Final value of function: 0.011724643409252167
# --------------------------------------------------
# Combination 6:
# Learning Rate: 0.3, Iterations: 5
# Final value of function: 0.022924814373254776
# --------------------------------------------------
# Combination 7:
# Learning Rate: 0.3, Iterations: 10
# Final value of function: 0.007583697326481342
# --------------------------------------------------
# Combination 8:
# Learning Rate: 0.3, Iterations: 15
# Final value of function: 0.002512644976377487
# --------------------------------------------------
# Combination 9:
# Learning Rate: 0.3, Iterations: 20
# Final value of function: 0.0008324942318722606
# --------------------------------------------------
# Combination 10:
# Learning Rate: 0.3, Iterations: 25
# Final value of function: 0.00027582357870414853
# --------------------------------------------------
# Combination 11:
# Learning Rate: 0.5, Iterations: 5
# Final value of function: 0.010175863280892372
# --------------------------------------------------
# Combination 12:
# Learning Rate: 0.5, Iterations: 10
# Final value of function: 0.0014988633338361979
# --------------------------------------------------
# Combination 13:
# Learning Rate: 0.5, Iterations: 15
# Final value of function: 0.00022077650646679103
# --------------------------------------------------
# Combination 14:
# Learning Rate: 0.5, Iterations: 20
# Final value of function: 3.2519488740945235e-05
# --------------------------------------------------
# Combination 15:
# Learning Rate: 0.5, Iterations: 25
# Final value of function: 4.789989361597691e-06
# --------------------------------------------------
# Combination 16:
# Learning Rate: 0.7, Iterations: 5
# Final value of function: 0.005457854829728603
# --------------------------------------------------
# Combination 17:
# Learning Rate: 0.7, Iterations: 10
# Final value of function: 0.00025810778606683016
# --------------------------------------------------
# Combination 18:
# Learning Rate: 0.7, Iterations: 15
# Final value of function: 1.565253478474915e-05
# --------------------------------------------------
# Combination 19:
# Learning Rate: 0.7, Iterations: 20
# Final value of function: 9.541084864395089e-07
# --------------------------------------------------
# Combination 20:
# Learning Rate: 0.7, Iterations: 25
# Final value of function: 5.816357528942717e-08
# --------------------------------------------------
# Combination 21:
# Learning Rate: 0.9, Iterations: 5
# Final value of function: 0.5881471037864685
# --------------------------------------------------
# Combination 22:
# Learning Rate: 0.9, Iterations: 10
# Final value of function: 0.3035772442817688
# --------------------------------------------------
# Combination 23:
# Learning Rate: 0.9, Iterations: 15
# Final value of function: 0.15708401799201965
# --------------------------------------------------
# Combination 24:
# Learning Rate: 0.9, Iterations: 20
# Final value of function: 0.08129112422466278
# --------------------------------------------------
# Combination 25:
# Learning Rate: 0.9, Iterations: 25
# Final value of function: 0.042068447917699814
# --------------------------------------------------
# Best Combination:
# Learning Rate: 0.7, Iterations: 25
# Final value of function: 5.816357528942717e-08
# --------------------------------------------------
# --------------------------------------------------
# All results for Adam:
# --------------------------------------------------
# Combination 1:
# Learning Rate: 0.1, Iterations: 5
# Final value of function: 0.20266200602054596
# --------------------------------------------------
# Combination 2:
# Learning Rate: 0.1, Iterations: 10
# Final value of function: 0.0076139746233820915
# --------------------------------------------------
# Combination 3:
# Learning Rate: 0.1, Iterations: 15
# Final value of function: 0.11001397669315338
# --------------------------------------------------
# Combination 4:
# Learning Rate: 0.1, Iterations: 20
# Final value of function: 0.07763669639825821
# --------------------------------------------------
# Combination 5:
# Learning Rate: 0.1, Iterations: 25
# Final value of function: 0.006319490261375904
# --------------------------------------------------
# Combination 6:
# Learning Rate: 0.3, Iterations: 5
# Final value of function: 0.2419552356004715
# --------------------------------------------------
# Combination 7:
# Learning Rate: 0.3, Iterations: 10
# Final value of function: 0.04914545267820358
# --------------------------------------------------
# Combination 8:
# Learning Rate: 0.3, Iterations: 15
# Final value of function: 0.10922256112098694
# --------------------------------------------------
# Combination 9:
# Learning Rate: 0.3, Iterations: 20
# Final value of function: 0.007606458850204945
# --------------------------------------------------
# Combination 10:
# Learning Rate: 0.3, Iterations: 25
# Final value of function: 0.04429048299789429
# --------------------------------------------------
# Combination 11:
# Learning Rate: 0.5, Iterations: 5
# Final value of function: 0.38444390892982483
# --------------------------------------------------
# Combination 12:
# Learning Rate: 0.5, Iterations: 10
# Final value of function: 0.16786333918571472
# --------------------------------------------------
# Combination 13:
# Learning Rate: 0.5, Iterations: 15
# Final value of function: 0.0003142718051094562
# --------------------------------------------------
# Combination 14:
# Learning Rate: 0.5, Iterations: 20
# Final value of function: 0.05473353713750839
# --------------------------------------------------
# Combination 15:
# Learning Rate: 0.5, Iterations: 25
# Final value of function: 0.041909024119377136
# --------------------------------------------------
# Combination 16:
# Learning Rate: 0.7, Iterations: 5
# Final value of function: 0.12576761841773987
# --------------------------------------------------
# Combination 17:
# Learning Rate: 0.7, Iterations: 10
# Final value of function: 0.17637135088443756
# --------------------------------------------------
# Combination 18:
# Learning Rate: 0.7, Iterations: 15
# Final value of function: 0.14480572938919067
# --------------------------------------------------
# Combination 19:
# Learning Rate: 0.7, Iterations: 20
# Final value of function: 0.04971326142549515
# --------------------------------------------------
# Combination 20:
# Learning Rate: 0.7, Iterations: 25
# Final value of function: 0.00291654234752059
# --------------------------------------------------
# Combination 21:
# Learning Rate: 0.9, Iterations: 5
# Final value of function: 0.0003349734761286527
# --------------------------------------------------
# Combination 22:
# Learning Rate: 0.9, Iterations: 10
# Final value of function: 0.004803783260285854
# --------------------------------------------------
# Combination 23:
# Learning Rate: 0.9, Iterations: 15
# Final value of function: 0.033749502152204514
# --------------------------------------------------
# Combination 24:
# Learning Rate: 0.9, Iterations: 20
# Final value of function: 0.054587963968515396
# --------------------------------------------------
# Combination 25:
# Learning Rate: 0.9, Iterations: 25
# Final value of function: 0.050295475870370865
# --------------------------------------------------
# Best Combination:
# Learning Rate: 0.5, Iterations: 15
# Final value of function: 0.0003142718051094562
# --------------------------------------------------
